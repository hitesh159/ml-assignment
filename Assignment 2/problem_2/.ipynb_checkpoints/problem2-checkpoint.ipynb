# %% [markdown]
# # READING THE DATA

# %%
import pandas as pd
train=pd.read_csv("problem_2_train.csv")
train.head()
# Out:
#       srno mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0  2851218      AN      7      500004              233                233
# 1  2838330      AJ     10      226010              233                233
# 2  2835781      AJ      2      110018              233                233
# 3  2838589      AM      2      110018              233                233
# 4  2855214      AN     21      110015              233                233
#
#    insuranceCompanyId custpincodecategory claimtype  custpincode  \
# 0                 131                   A      ADLD       500001
# 1                 131                   A      ADLD       226022
# 2                 228                   A      ADLD       110018
# 3                 228                   B      ADLD       124001
# 4                 131                   A      ADLD       201301
#
#   memcreateddate mobilepurchasedate claimintdate  servicecntrid  \
# 0     2017-04-27         2016-12-02   2018-02-08           4403
# 1     2017-03-06         2017-03-05   2018-02-04           4444
# 2     2018-02-01         2018-01-27   2018-02-03           4388
# 3     2018-01-17         2018-01-31   2018-02-04           4092
# 4     2018-01-23         2018-01-20   2018-02-09           4580
#
#   pickupStartdate  tat_in_days
# 0      2018-02-13            5
# 1      2018-02-08           12
# 2      2018-02-12            9
# 3      2018-02-14            9
# 4      2018-02-14            8

# %% [markdown]
# # PREPROCESSING
# CONVERTING THE DATES IN THE DATASET TO TIMESTAMPS

# %%
import time
import datetime
k=[]
k1=[]
k2=[]
k3=[]
for index,row in train.iterrows():
    s=row["pickupStartdate"]
    row.pickupStartdate=time.mktime(datetime.datetime.strptime(s,"%Y-%m-%d").timetuple())
    k.append(row.pickupStartdate*(10**(-9)))
    s=row["claimintdate"]
    row.claimintdate=time.mktime(datetime.datetime.strptime(s,"%Y-%m-%d").timetuple())
    k1.append(row.claimintdate*(10**(-9)))
    s=row["mobilepurchasedate"]
    row.mobilepurchasedate=time.mktime(datetime.datetime.strptime(s,"%Y-%m-%d").timetuple())
    k2.append(row.mobilepurchasedate*(10**(-9)))
    s=row["memcreateddate"]
    row.memcreateddate=time.mktime(datetime.datetime.strptime(s,"%Y-%m-%d").timetuple())
    k3.append(row.memcreateddate*(10**(-9)))
    #print(row.pickupStartdate)
train["pickupStartdate"]=k
train["claimintdate"]=k1
train["mobilepurchasedate"]=k2
train["memcreateddate"]=k3

# %% [markdown]
# adding column diff

# %%
k3=[]
for i in range(len(k2)):
    k3.append((k[i]-k1[i])*10000)
train["diff"]=k3

# %%
train.head()
# Out:
#       srno mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0  2851218      AN      7      500004              233                233
# 1  2838330      AJ     10      226010              233                233
# 2  2835781      AJ      2      110018              233                233
# 3  2838589      AM      2      110018              233                233
# 4  2855214      AN     21      110015              233                233
#
#    insuranceCompanyId custpincodecategory claimtype  custpincode  \
# 0                 131                   A      ADLD       500001
# 1                 131                   A      ADLD       226022
# 2                 228                   A      ADLD       110018
# 3                 228                   B      ADLD       124001
# 4                 131                   A      ADLD       201301
#
#    memcreateddate  mobilepurchasedate  claimintdate  servicecntrid  \
# 0        1.493231            1.480617      1.518028           4403
# 1        1.488739            1.488652      1.517683           4444
# 2        1.517423            1.516991      1.517596           4388
# 3        1.516127            1.517337      1.517683           4092
# 4        1.516646            1.516387      1.518115           4580
#
#    pickupStartdate  tat_in_days   diff
# 0         1.518460            5  4.320
# 1         1.518028           12  3.456
# 2         1.518374            9  7.776
# 3         1.518547            9  8.640
# 4         1.518547            8  4.320

# %%
train.custpincodecategory.value_counts()
# Out:
# A    4020
# B    1346
# C     554
# 0     186
# D     144
# Name: custpincodecategory, dtype: int64

# %% [markdown]
# # ENCODING THE CATEGORICAL DATA

# %%
from sklearn import preprocessing 
from sklearn.preprocessing import LabelEncoder
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
train['custpincodecategory']= label_encoder.fit_transform(train['custpincodecategory'])
train['mobmake']= label_encoder.fit_transform(train['mobmake'])
train['claimtype']= label_encoder.fit_transform(train['claimtype'])

# %%
train.head()
train.srno.value_counts()
# Out:
# 2951287    4
# 2865502    4
# 2885668    3
# 3038517    3
# 2956372    2
# 2891966    2
# 3011894    2
# 3012946    2
# 3044892    2
# 2934881    2
# 2819467    2
# 3056440    2
# 2822557    2
# 2878000    2
# 3039486    2
# 2960986    2
# 3039983    2
# 2923461    2
# 2882355    2
# 3039212    2
# 3019136    2
# 3048248    2
# 3051276    2
# 3019781    2
# 2961709    2
# 2822700    2
# 3022198    2
# 3074237    2
# 3005015    2
# 3071319    2
#           ..
# 2823520    1
# 3038561    1
# 2819426    1
# 3009891    1
# 2979172    1
# 2899301    1
# 2905420    1
# 2957692    1
# 3013961    1
# 3001671    1
# 3030317    1
# 2860334    1
# 2908697    1
# 3044515    1
# 3079473    1
# 2870579    1
# 2889012    1
# 2906118    1
# 3052856    1
# 2927931    1
# 2880828    1
# 2858301    1
# 2999614    1
# 2870591    1
# 2873437    1
# 3022145    1
# 3073710    1
# 2970112    1
# 2827590    1
# 2994662    1
# Name: srno, Length: 6147, dtype: int64

# %% [markdown]
# # APPLYING LINEAR REGRESSION

# %%
feature_cols=["srno","memcreateddate","hubid","mobilepurchasedate","pickupStartdate","claimtype","pickuppartnerid","diff","deliverypartnerid","insuranceCompanyId","servicecntrid","custpincodecategory","mobmake","claimintdate"]
X=train[feature_cols]
y=train.tat_in_days

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred=linreg.predict(X_test)
print(y_test,y_pred)
# Out:
# 1163     9
# 2743    11
# 4625    23
# 5569    11
# 4948    14
# 4426     9
# 2478    20
# 5509     6
# 5501     9
# 3847    10
# 5134    16
# 4428     8
# 4754    13
# 3100    19
# 5243    31
# 3909    13
# 1817    15
# 4694    15
# 2116    10
# 1697     8
# 3554     6
# 3305    23
# 5343     6
# 5473     6
# 2040    17
# 4447    13
# 6197    10
# 1929    21
# 5000    12
# 6011     8
#         ..
# 5505     8
# 4096    16
# 1077    11
# 4589    13
# 1807    14
# 3085    20
# 2600     8
# 3189    21
# 6109    19
# 3924    16
# 900      8
# 1386    10
# 5240    12
# 4716    13
# 4352    23
# 5356    13
# 1357     7
# 3234     8
# 16      12
# 4183    11
# 2534     6
# 2754    14
# 4656    14
# 761      8
# 2537    10
# 1061     9
# 4195    18
# 5992    10
# 3078    12
# 3525     7
# Name: tat_in_days, Length: 1563, dtype: int64 [13.79734278 10.20484625 14.38094514 ... 12.60433077 12.26738483
#  11.73290559]

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 4.989999917605614

# %%
linreg.coef_
# Out:
# array([ 3.91268908e-06,  1.06330623e+01,  1.60912430e-03, -1.67857320e+01,
#        -3.10766788e+02,  1.54492163e+01, -7.38889274e-03,  8.12314406e-02,
#        -9.18942152e-03, -2.88248163e-03, -3.60481455e-03,  1.04610206e+00,
#         1.18183554e-01, -3.10766796e+02])

# %% [markdown]
# # APPLYING KNN

# %%
from sklearn import neighbors
n_neighbors=5
knn=neighbors.KNeighborsRegressor(n_neighbors,weights='uniform')
knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 5.404623503476576

# %% [markdown]
# # APPLYING RIDGE

# %%
from sklearn import tree
from sklearn import linear_model
model=linear_model.Ridge()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 4.989180531443785

# %%
train.columns
# Out:
# Index(['srno', 'mobmake', 'hubid', 'hubpincode', 'pickuppartnerid',
#        'deliverypartnerid', 'insuranceCompanyId', 'custpincodecategory',
#        'claimtype', 'custpincode', 'memcreateddate', 'mobilepurchasedate',
#        'claimintdate', 'servicecntrid', 'pickupStartdate', 'tat_in_days',
#        'diff'],
#       dtype='object')

# %% [markdown]
# # REMOVING COLUMNS srno mobmake hubpincode claimtype
# # and applying svm

# %%
feature_cols=["hubid","memcreateddate","insuranceCompanyId","servicecntrid","custpincodecategory","pickuppartnerid","mobilepurchasedate","deliverypartnerid",'pickupStartdate',"claimtype","claimintdate"]
X=train[feature_cols]
y=train.tat_in_days
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=101)

# %%
from sklearn import svm
svm_reg=svm.SVR()
svm_reg.fit(X_train,y_train)
y_pred=svm_reg.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 4.5822974190613115

# %% [markdown]
# # applying descision tree

# %%
feature_cols=["hubid","memcreateddate","insuranceCompanyId","servicecntrid","custpincodecategory","pickuppartnerid","mobilepurchasedate","deliverypartnerid",'pickupStartdate',"claimtype","claimintdate"]
X=train[feature_cols]
y=train.tat_in_days
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1)

# %%
dec = tree.DecisionTreeRegressor(max_depth=1)
dec.fit(X_train,y_train)
y_pred=dec.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 5.177018440869705

# %% [markdown]
# # applying gradientboost

# %%
feature_cols=["memcreateddate","insuranceCompanyId","servicecntrid","custpincodecategory","pickuppartnerid","mobilepurchasedate","deliverypartnerid",'pickupStartdate',"claimtype","claimintdate"]
X=train[feature_cols]
y=train.tat_in_days
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=101 )

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb=GradientBoostingRegressor(n_estimators =200)
gb.fit(X_train,y_train)
y_pred=gb.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 4.161820943312321

# %% [markdown]
# # appyling random forest

# %%
feature_cols=["memcreateddate","insuranceCompanyId","servicecntrid","custpincodecategory","pickuppartnerid","mobilepurchasedate","deliverypartnerid",'pickupStartdate',"claimtype","claimintdate"]
X=train[feature_cols]
y=train.tat_in_days
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=5,
                              n_estimators=100)
regr.fit(X_train,y_train)
y_pred=regr.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 4.723346018102905

# %% [markdown]
# # saving to csv using gradient boost min rms=4.16

# %%
test=pd.read_csv("problem_2_test.csv")
test.head()
# Out:
#       srno mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0  2829088      AN      3      560011              233                233
# 1  2829866      AJ      2      110018              233                233
# 2  2894489      AJ      3      560011              233                233
# 3  2876708      AJ      2      110018              233                233
# 4  2890283      AN     22      400104              233                233
#
#    insuranceCompanyId custpincodecategory claimtype  custpincode  \
# 0                 131                   A      ADLD       560093
# 1                 228                   A      ADLD       110034
# 2                 228                   C      ADLD       590014
# 3                 228                   B      ADLD       250110
# 4                 131                   C      ADLD       496001
#
#   memcreateddate mobilepurchasedate claimintdate  servicecntrid  \
# 0     2017-07-30         2017-07-27   2018-02-01           4467
# 1     2017-07-17         2017-01-25   2018-02-01           4388
# 2     2018-01-12         2018-01-11   2018-02-21           4460
# 3     2017-08-07         2017-05-21   2018-02-16           4388
# 4     2017-11-10         2017-09-22   2018-02-20           4581
#
#   pickupStartdate
# 0      2018-02-06
# 1      2018-02-08
# 2      2018-02-28
# 3      2018-02-26
# 4      2018-02-23

# %%
import time
import datetime
k=[]
k1=[]
k2=[]
k3=[]
for index,row in test.iterrows():
    s=row["pickupStartdate"]
    row.pickupStartdate=time.mktime(datetime.datetime.strptime(s,"%Y-%m-%d").timetuple())
    k.append(row.pickupStartdate*(10**(-9)))
    s=row["claimintdate"]
    row.claimintdate=time.mktime(datetime.datetime.strptime(s,"%Y-%m-%d").timetuple())
    k1.append(row.claimintdate*(10**(-9)))
    s=row["mobilepurchasedate"]
    row.mobilepurchasedate=time.mktime(datetime.datetime.strptime(s,"%Y-%m-%d").timetuple())
    k2.append(row.mobilepurchasedate*(10**(-9)))
    s=row["memcreateddate"]
    row.memcreateddate=time.mktime(datetime.datetime.strptime(s,"%Y-%m-%d").timetuple())
    k3.append(row.memcreateddate*(10**(-9)))
    #print(row.pickupStartdate)
test["pickupStartdate"]=k
test["claimintdate"]=k1
test["mobilepurchasedate"]=k2
test["memcreateddate"]=k3

# %%
k3=[]
for i in range(len(k2)):
    k3.append((k[i]-k1[i])*10000)
test["diff"]=k3

# %%
test
# Out:
#          srno mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0     2829088      AN      3      560011              233                233
# 1     2829866      AJ      2      110018              233                233
# 2     2894489      AJ      3      560011              233                233
# 3     2876708      AJ      2      110018              233                233
# 4     2890283      AN     22      400104              233                233
# 5     2897438       C      6      160059              233                233
# 6     2849010       C      2      110018              233                233
# 7     2887783       U      2      110018              233                233
# 8     2941799      AN     21      110015              233                233
# 9     2973976      AN     22      400104              233                233
# 10    2977421       J      2      110018              233                233
# 11    2982990      AN     26      560066              233                233
# 12    2979785      AJ      2      110018              233                233
# 13    2984029       H      1      400059              233                233
# 14    3012909      AD      2      110018              233                233
# 15    3030307      AJ     27      110034              233                233
# 16    3048314      AN      7      500004              233                233
# 17    3060524       C      2      110018              233                233
# 18    3064259      AN     21      110015              233                233
# 19    3057867       C      2      110018              308                233
# 20    2870652      AJ      3      560011              233                245
# 21    2920134      AJ      3      560011              233                245
# 22    2866111      AN     21      110015              233                233
# 23    2908430      AJ      3      560011              233                233
# 24    2920849      AN     22      400104              233                233
# 25    2884266      AF      5      380009              233                245
# 26    2819466      AN      4      600024              233                233
# 27    2858437      AN     17      800001              233                233
# 28    3050523       C      2      110018              308                233
# 29    2876140      AN     22      400104              233                245
# ...       ...     ...    ...         ...              ...                ...
# 2086  2973530      AN     26      560066              233                233
# 2087  3031983      AN     22      400104              233                233
# 2088  2841201       C      2      110018              233                233
# 2089  2906715      AN      3      560011              233                233
# 2090  2990607      AJ     25      560037              201                233
# 2091  2843872       C     12      302006              233                233
# 2092  2889644      AJ      2      110018              233                233
# 2093  2906784      AN      8      700064              233                233
# 2094  2891769       C     12      302006              201                233
# 2095  2898703      AN      3      560011              233                233
# 2096  2910059       J      2      110018              233                233
# 2097  2953259      AJ      2      110018              201                233
# 2098  2947954      AN     21      110015              233                233
# 2099  2956245      AI      6      160059              233                233
# 2100  2931393      AN     21      110015              308                233
# 2101  3039774       C      2      110018              233                233
# 2102  3074175      AN      7      500004              233                233
# 2103  3075677      AJ     23      400001              233                233
# 2104  2981955      AJ      2      110018              308                233
# 2105  3044848       S     24      110092              233                233
# 2106  2889932      AN      3      560011              233                245
# 2107  2820342      AN     22      400104              233                233
# 2108  2879400       C      4      600024              233                233
# 2109  2894451      AN      4      600024              201                233
# 2110  3000751      AJ     23      400001              233                233
# 2111  2838635      AJ      2      110018              233                233
# 2112  2879869      AN     22      400104              233                233
# 2113  2853014       C     12      302006              233                233
# 2114  2915495      AN     22      400104              233                233
# 2115  2937360       C      2      110018              233                233
#
#       insuranceCompanyId custpincodecategory claimtype  custpincode  \
# 0                    131                   A      ADLD       560093
# 1                    228                   A      ADLD       110034
# 2                    228                   C      ADLD       590014
# 3                    228                   B      ADLD       250110
# 4                    131                   C      ADLD       496001
# 5                    131                   B      ADLD       160036
# 6                    228                   A      ADLD       110065
# 7                    228                   A      ADLD       110092
# 8                    131                   B      ADLD       124001
# 9                    131                   A      ADLD       400011
# 10                   131                   A      ADLD       110006
# 11                   131                   A      ADLD       600097
# 12                   131                   A      ADLD       201301
# 13                   131                   B      ADLD       440027
# 14                   131                   A      ADLD       201301
# 15                   131                   A      ADLD       110092
# 16                   131                   A      ADLD       500011
# 17                   228                   A      ADLD       110029
# 18                   131                   B      ADLD       124001
# 19                   228                   A      ADLD       110092
# 20                   228                   A      ADLD       560102
# 21                   131                   A      ADLD       560062
# 22                   131                   A      ADLD       122002
# 23                   131                   B      ADLD       570029
# 24                   131                   B      ADLD       462043
# 25                   131                   A      ADLD       380008
# 26                   131                   B      ADLD       636016
# 27                   131                   A      ADLD       800001
# 28                   131                   A      ADLD       110027
# 29                   131                   B      ADLD       385001
# ...                  ...                 ...       ...          ...
# 2086                 131                   A      ADLD       560071
# 2087                 131                   A      ADLD       411004
# 2088                 228                   A      ADLD       122001
# 2089                 131                   C      ADLD       583132
# 2090                 131                   D      ADLD       635104
# 2091                 228                   A      ADLD       302018
# 2092                 228                   A      ADLD       110058
# 2093                 131                   A      ADLD       700089
# 2094                 228                   0      ADLD       326001
# 2095                 228                   B      ADLD       590011
# 2096                 131                   A      ADLD       110096
# 2097                 228                   0      ADLD       201102
# 2098                 131                   B      ADLD       245101
# 2099                 131                   B      ADLD       133001
# 2100                 131                   A      ADLD       110002
# 2101                 228                   A      ADLD       110058
# 2102                 131                   B      ADLD       522006
# 2103                 228                   A      ADLD       400601
# 2104                 228                   A      ADLD       122002
# 2105                 228                   B      ADLD       282001
# 2106                 228                   A      ADLD       560068
# 2107                 131                   A      ADLD       400708
# 2108                 131                   A      ADLD       600041
# 2109                 131                   D      ADLD       636808
# 2110                 131                   A      ADLD       421003
# 2111                 228                   A      ADLD       110032
# 2112                 131                   A      ADLD       411048
# 2113                 228                   A      ADLD       302017
# 2114                 131                   A      ADLD       380004
# 2115                 131                   A      ADLD       110087
#
#       memcreateddate  mobilepurchasedate  claimintdate  servicecntrid  \
# 0           1.501353            1.501094      1.517423           4467
# 1           1.500230            1.485283      1.517423           4388
# 2           1.515695            1.515609      1.519151           4460
# 3           1.502044            1.495305      1.518719           4388
# 4           1.510252            1.506019      1.519065           4581
# 5           1.513017            1.512844      1.519238           4549
# 6           1.504809            1.494095      1.517942           4091
# 7           1.517510            1.506019      1.518979           4095
# 8           1.514659            1.498415      1.520188           4580
# 9           1.495391            1.522003      1.520879           4581
# 10          1.514659            1.514140      1.520879           4154
# 11          1.497206            1.497033      1.521052           5001
# 12          1.508783            1.508524      1.520966           4388
# 13          1.519497            1.518460      1.521052           4011
# 14          1.510943            1.499711      1.521830           4148
# 15          1.510771            1.503599      1.522175           4388
# 16          1.517942            1.493059      1.522607           4403
# 17          1.521052            1.518028      1.522953           4094
# 18          1.493923            1.493663      1.523039           4580
# 19          1.521311            1.521311      1.522867           4550
# 20          1.499711            1.470335      1.518547           4460
# 21          1.490639            1.490553      1.519670           4460
# 22          1.494182            1.493923      1.518460           4580
# 23          1.514399            1.514399      1.519583           4460
# 24          1.496860            1.496428      1.519670           4581
# 25          1.487875            1.487702      1.518979           4039
# 26          1.494009            1.497551      1.517251           4490
# 27          1.512758            1.506105      1.518201           4538
# 28          1.497206            1.496169      1.522694           4550
# 29          1.505673            1.504895      1.518719           4581
# ...              ...                 ...           ...            ...
# 2086        1.489775            1.489775      1.520879           5001
# 2087        1.462905            1.462559      1.522175           4581
# 2088        1.508870            1.476815      1.517769           4091
# 2089        1.499452            1.496687      1.519497           5001
# 2090        1.518460            1.511375      1.521225           4460
# 2091        1.504204            1.454438      1.517855           4453
# 2092        1.515523            1.469731      1.519065           4388
# 2093        1.492886            1.492799      1.519497           4508
# 2094        1.517337            1.488393      1.519151           4407
# 2095        1.511203            1.489084      1.519238           4467
# 2096        1.489603            1.488566      1.519583           4154
# 2097        1.517596            1.517423      1.520361           4388
# 2098        1.503340            1.499798      1.520275           4580
# 2099        1.515782            1.515782      1.520447           4437
# 2100        1.508438            1.508265      1.520015           4580
# 2101        1.518719            1.486838      1.522348           4550
# 2102        1.494873            1.524422      1.523385           4403
# 2103        1.520534            1.520534      1.523385           4398
# 2104        1.519324            1.506278      1.521052           4388
# 2105        1.520102            1.502735      1.522521           4150
# 2106        1.508179            1.487788      1.519065           4467
# 2107        1.492367            1.492108      1.517251           4581
# 2108        1.496687            1.496687      1.518806           4483
# 2109        1.507833            1.507574      1.519151           4490
# 2110        1.490899            1.490639      1.521484           4398
# 2111        1.501526            1.488652      1.517683           4388
# 2112        1.500835            1.500662      1.518806           4581
# 2113        1.510079            1.499366      1.518028           4453
# 2114        1.516300            1.506278      1.519670           4581
# 2115        1.467571            1.467484      1.520015           4550
#
#       pickupStartdate    diff
# 0            1.517855   4.320
# 1            1.518028   6.048
# 2            1.519756   6.048
# 3            1.519583   8.640
# 4            1.519324   2.592
# 5            1.519670   4.320
# 6            1.519929  19.872
# 7            1.519583   6.048
# 8            1.520966   7.776
# 9            1.521225   3.456
# 10           1.521398   5.184
# 11           1.521484   4.320
# 12           1.521484   5.184
# 13           1.521398   3.456
# 14           1.522262   4.320
# 15           1.522435   2.592
# 16           1.523299   6.912
# 17           1.523471   5.184
# 18           1.523903   8.640
# 19           1.523817   9.504
# 20           1.518633   0.864
# 21           1.519843   1.728
# 22           1.518806   3.456
# 23           1.520015   4.320
# 24           1.520015   3.456
# 25           1.519151   1.728
# 26           1.517596   3.456
# 27           1.518547   3.456
# 28           1.522867   1.728
# 29           1.519065   3.456
# ...               ...     ...
# 2086         1.521225   3.456
# 2087         1.522348   1.728
# 2088         1.518115   3.456
# 2089         1.520361   8.640
# 2090         1.522262  10.368
# 2091         1.518547   6.912
# 2092         1.519324   2.592
# 2093         1.519843   3.456
# 2094         1.520188  10.368
# 2095         1.520275  10.368
# 2096         1.520102   5.184
# 2097         1.521052   6.912
# 2098         1.520534   2.592
# 2099         1.520620   1.728
# 2100         1.521830  18.144
# 2101         1.523471  11.232
# 2102         1.523903   5.184
# 2103         1.523817   4.320
# 2104         1.521225   1.728
# 2105         1.522694   1.728
# 2106         1.519583   5.184
# 2107         1.519238  19.872
# 2108         1.519065   2.592
# 2109         1.520275  11.232
# 2110         1.521657   1.728
# 2111         1.517769   0.864
# 2112         1.519151   3.456
# 2113         1.518547   5.184
# 2114         1.519929   2.592
# 2115         1.520534   5.184
#
# [2116 rows x 16 columns]

# %%
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
test['custpincodecategory']= label_encoder.fit_transform(test['custpincodecategory'])
test['mobmake']= label_encoder.fit_transform(test['mobmake'])
test['claimtype']= label_encoder.fit_transform(test['claimtype'])

# %%
len(test)
# Out:
# 2116

# %%
feature_cols=["memcreateddate","insuranceCompanyId","servicecntrid","custpincodecategory","pickuppartnerid","mobilepurchasedate","deliverypartnerid",'pickupStartdate',"claimtype","claimintdate"]
X_test=test[feature_cols]

# %%
len(X_test)
# Out:
# 2116

# %%
y_pred=gb.predict(X_test)

# %%
len(y_pred)
# Out:
# 2116

# %%
res=pd.DataFrame({'tat_in_days':y_pred})

# %%
res.to_csv("solutions.csv")
